# %%
import pandas as pd
import re
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import nltk
from nltk.corpus import webtext
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
import operator
from nltk.corpus import stopwords
from random import shuffle
import numpy as np
import random
from sklearn.cluster import KMeans

# %%
taylor_df = pd.read_csv('taylor_swift_lyrics.csv')
beyonce_df = pd.read_csv('beyonce_lyrics.csv')
ed_df = pd.read_csv('EdSheeran.csv')

# %%
taylor_df.columns
# Out:
# Index(['Artist ', 'Album', 'Title ', 'Lyrics'], dtype='object')

# %%
beyonce_df.columns
# Out:
# Index(['line', 'song_id', 'song_name', 'artist_id', 'artist_name',
#        'song_line'],
#       dtype='object')

# %%
print(pd.unique(beyonce_df.song_name))
# Out:
# ['1+1' "2017 Grammy's Best Urban Contemporary Album Speech"
#  '6 Inch (Ft.\xa0The\xa0Weeknd)' '7/11' '7/11 (Homecoming Live)'
#  'All I Could Do Was Cry' 'All Night'
#  'Amor Gitano (Ft.\xa0Alejandro\xa0Fernández)' 'Anger' 'Apathy'
#  'Apology to Fans' 'At Last' 'At Last (Live)' 'Ave Maria'
#  'Ave Maria (Live)' 'A Woman Like Me' 'Baby Boy (Ft.\xa0Sean\xa0Paul)'
#  'Baby Boy (Alternate Version) (Ft.\xa0Sean\xa0Paul)'
#  'Baby Boy (Alternative Version) (Ft.\xa0Sean\xa0Paul)'
#  'Baby Boy (Homecoming Live)' "Baby Boy [Junior's World Mixshow]"
#  'Baby Boy (Live)' 'Baby Boy Medley (The Beyonce Experience Live)'
#  "Baby, You're The Only Man" 'Back to Black (Ft.\xa0André\xa03000)'
#  'Back Up' 'Beautiful Liar (Bello Embustero) [Spanish Version]'
#  'Beautiful Liar (Beyoncé Experience Live)'
#  'Beautiful Liar (Spanglish Version)' 'Before I Let Go'
#  'Best Thing I Never Had' 'Best Thing I Never Had (Lars B Remix)'
#  'Best Thing I Never Had [Original Version]' 'Be With You'
# ...

# %%
## without trimming any features, let's take a look at the common words written by these artist
